# %% [markdown]
# ## 모델 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers;
# !pip install sentencepiece;
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 49.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers)
#   Downloading huggingface_hub-0.15.1-py3-none-any.whl (236 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 21.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 97.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.15.1 tokenizers-0.13.3 transformers-4.29.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 16.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.1.99

# %%
from transformers import (
    PreTrainedTokenizerFast as BaseGPT2Tokenizer,
    EncoderDecoderModel,
    DataCollatorForSeq2Seq,
)
import pickle
from drive.MyDrive.WARNING_PRIVATE_FOLDER.OSSP2AntiGPT9.ai.tokenization_kobert import KoBertTokenizer
#from drive.MyDrive.WARNING_PRIVATE_FOLDER.OSSP2AntiGPT9.ai.lib import tokenization_kobert
import json
src_tokenizer = KoBertTokenizer.from_pretrained('monologg/kobert')
# Out:
# Downloading (…)zer_78b3253a26.model:   0%|          | 0.00/371k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/77.8k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/51.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/426 [00:00<?, ?B/s]
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'BertTokenizer'.
# The class this function is called from is 'KoBertTokenizer'.

# %%
class GPT2Tokenizer(BaseGPT2Tokenizer):
    def build_inputs_with_special_tokens(self, token_ids, _):
        return token_ids + [self.eos_token_id]
trg_tokenizer = GPT2Tokenizer.from_pretrained("skt/kogpt2-base-v2",
  bos_token='</s>', eos_token='</s>', unk_token='<unk>',
  pad_token='<pad>', mask_token='<mask>')
# Out:
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.83M [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]

# %%
# %cd /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai
# with open('/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/save_src_tk.pickle','rb') as f:
#     src_tokenizer = pickle.load(f)
# there's an error in this code when activating in local
# Out:
# /content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai

# %%
with open("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/standard_to_dialect/no_commit/added_tokens_trg.json", 'rb') as f:
    dw_dict = json.load(f)
dict_swap = {v:k for k,v in dw_dict.items()}
ma=54000
mi=51200
for i in range(51200,54001):
    trg_tokenizer.add_tokens(dict_swap[i])

# %%
model = EncoderDecoderModel.from_pretrained('leadawon/ossp-reverse-v0_3')
model.eval()
model.config.decoder_start_token_id = trg_tokenizer.bos_token_id
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/5.19k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.02G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]

# %% [markdown]
# ## 테스트데이터 불러오기

# %%
def read_input(path):
    with open(path, 'rb') as f:
        test_dict = json.load(f)
    test_standard = []
    test_dialect = []
    for pairs in test_dict['utterance']:
        test_standard.append(pairs['standard_form'])
        test_dialect.append(pairs['dialect_form'])

    return test_standard ,test_dialect

# %%
test_s ,test_d= read_input("/content/drive/MyDrive/WARNING_PRIVATE_FOLDER/OSSP2AntiGPT9/ai/no_commit/test_data_big.json")

# %%
def translate(text):
    embeddings = src_tokenizer(text, return_attention_mask=False, return_token_type_ids=False, return_tensors='pt')
    embeddings = {k: v for k, v in embeddings.items()}
    output = model.generate(**embeddings)[0, 1:-1]
    tmp = trg_tokenizer.decode(output.cpu())
    return tmp

# %%
print("size of full : ",len(test_s))
# Out:
# size of full :  12451

# %%
for i in range(len(test_d)):
    sr_text = test_s[i] # standard
    tg_text = translate(sr_text) # translate
    print("source_text : ",sr_text)
    print("result :      ",tg_text)
    print("ground_truth :",test_d[i])
    print()
    print()
    if i%50==0:
        print("iteration num : ",i)
        break
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1255: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1346: UserWarning: Using `max_length`'s default (20) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# source_text :  언니 만나서 반가워 아 오늘 제주 방언 에이 아이 데이터
# result :       언니 만낭 반가 워 아 오늘 제주 방언 에이 아이 데이터
# ground_truth : 언니 만낭 반가워 아 오늘 제주 방언 에이 아이 데이터
#
#
# iteration num :  0

# %% [markdown]
# ## scoring

# %%
# !pip install "sacrebleu[ko]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sacrebleu[ko]
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 3.8 MB/s eta 0:00:00
# Collecting portalocker (from sacrebleu[ko])
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (0.8.10)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (1.22.4)
# Collecting colorama (from sacrebleu[ko])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu[ko]) (4.9.2)
# Collecting mecab-ko==1.0.0 (from sacrebleu[ko])
#   Downloading mecab_ko-1.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.5/582.5 kB 17.6 MB/s eta 0:00:00
# Collecting mecab-ko-dic<2.0,>=1.0 (from sacrebleu[ko])
#   Downloading mecab-ko-dic-1.0.0.tar.gz (33.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 15.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: mecab-ko-dic
#   Building wheel for mecab-ko-dic (setup.py) ... done
#   Created wheel for mecab-ko-dic: filename=mecab_ko_dic-1.0.0-py3-none-any.whl size=33424394 sha256=bf340df8d50e7de0c36e41b8a9fb1c2b1001d3c2d428c20a3be10012b5376d47
#   Stored in directory: /root/.cache/pip/wheels/0d/46/b8/996432c9998690a5a66fb82f6499222e48a23ff5b6c7d80322
# Successfully built mecab-ko-dic
# Installing collected packages: mecab-ko-dic, portalocker, mecab-ko, colorama, sacrebleu
# Successfully installed colorama-0.4.6 mecab-ko-1.0.0 mecab-ko-dic-1.0.0 portalocker-2.7.0 sacrebleu-2.3.1

# %%
from sacrebleu.metrics import BLEU

# %%
def score_B(sr_text, tg_text):

    candidate=[tg_text]
    reference=[[sr_text]]

    bleu = BLEU()

    bleuscore = bleu.corpus_score(candidate,reference).score
    return bleuscore
    #bleu_save.append(bleuscore)

# %%
sumation = 0
NUM_OF_TEST = 500
for i in range(len(test_s)):
    sr_text = test_s[i] # standard
    tg_text = translate(sr_text) # translate
    print("source_text : ",sr_text)
    print("result      : ",tg_text)
    print("ground_truth: ",test_d[i])
    scr = score_B(tg_text.strip(),test_d[i].strip())
    sumation += scr
    print("sum_score : {}".format(sumation/(i+1)))
    print("bleu_socre  :  {:.2f}".format(scr))
    print()
    print()
    if i%50==0:
        print("iteration num : ",i)
    if i==NUM_OF_TEST:
        break
print("at_last_sum_score : {}".format(sumation/NUM_OF_TEST))
# Out:
# source_text :  언니 만나서 반가워 아 오늘 제주 방언 에이 아이 데이터
# result      :  언니 만낭 반가 워 아 오늘 제주 방언 에이 아이 데이터
# ground_truth:  언니 만낭 반가워 아 오늘 제주 방언 에이 아이 데이터
# sum_score : 63.981667416455416
# bleu_socre  :  63.98
#
#
# iteration num :  0
# source_text :  어 명절 설 명절 추석 명절 요로케 나누어서 해볼 거예요
# result      :  어 맹질 설 맹질 추석 맹질 요로케 갈랑 해볼 거
# ground_truth:  어 명절 설 명절 추석 명절 요로케 나누어서 해볼 거예
# sum_score : 35.12816136372508
# bleu_socre  :  6.27
#
#
# source_text :  자 그러면 이제부터 얘기해 봐요
# result      :  자 그러면 이제부터 얘기 해 봅서
# ground_truth:  자 그믄 이제부터 얘기해 보게예
# sum_score : 26.885640138818488
# bleu_socre  :  10.40
#
#
# source_text :  어 그러면 언니네 설 명절 때 음식 어떻게 해
# result      :  어 게믄 언니네 설 명절 때 음식 어떵 해
# ground_truth:  어 그믄 언니네 설 명절 때 음식 어떵 해
# sum_score : 38.92982644787236
# bleu_socre  :  75.06
#
#
# source_text :  음식을 막 준비했던 기억이 나
# result      :  음식을 막 준비했던 기억이 나맨
# ground_truth:  음식을 막 준비했던 기억이 나게
# sum_score : 44.51866725782632
# bleu_socre  :  66.87
#
#
# source_text :  밀가룬지 쌀가룬지를 모르겠어  근데 그거를 푹
# result      :  밀가루사 쌀가룬지를 모르크라 근데 그거를 푹
# ground_truth:  밀가룬지 쌀가룬지를 모르크라  근데 그거를 푹
# sum_score : 49.762817475715146
# bleu_socre  :  75.98
#
#
# source_text :  반죽을 해서 날 납작하게
# result      :  반죽을 해영 날 납작하게시리
# ground_truth:  반죽을 해그내 날 납작하게
# sum_score : 45.3675424279401
# bleu_socre  :  19.00
#
#
# source_text :  게 밀어 밀대로 밀어서
# result      :  게 밀어 밀대로 밀엉으네
# ground_truth:  게 밀어 밀대로 밀어그내
# sum_score : 47.12914409321459
# bleu_socre  :  59.46
#
#
# source_text :  어 방바닥에다 따뜻한 방
# result      :  어 방바닥에다 또똣한 방
# ground_truth:  어 방바닥에다 똣똣한 방
# sum_score : 45.82094353389379
# bleu_socre  :  35.36
#
#
# source_text :  밀가룬지 쌀가룬지 몰라 근데 이케 떼가지고 이케 밀어서
# result      :  밀가루사 쌀가룬지 몰라 근데 이케 떼가지고 이케 밀
# ground_truth:  밀가룬지 쌀가룬지 몰라 근데 이케 떼가지고 이케 밀어그내
# sum_score : 48.042598513675614
# bleu_socre  :  68.04
#
#
# source_text :  아니 기름떡하고 다르지
# result      :  아니 지름떡하고 틀리주게
# ground_truth:  아니 기름떡하고 달르주게
# sum_score : 43.67508955788692
# bleu_socre  :  0.00
#
#
# source_text :  과즐을 하는데 그거를 으 밀어서 인제 바짝 마르잖아
# result      :  과즐을 하는데 그거를 으 밀어서 인제 바짝 마르네
# ground_truth:  과즐을 하는데 그거를 으 밀어그내 인제 바짝 마르잖아
# sum_score : 43.461612235567344
# bleu_socre  :  41.11
#
#
# source_text :  엿을 확 입혀서 거기다가 그
# result      :  엿을 확 입형 거기다가 그
# ground_truth:  엿을 확 입혀그내 거기다가 그
# sum_score : 42.44254621541352
# bleu_socre  :  30.21
#
#
# source_text :  그냥 쌀을 통째로 해가지고 그거에다  이렇게 발라서 이
# result      :  그냥 쌀을 통째로 해가지고 그거에다 이렇게 발랑 이
# ground_truth:  그냥 쌀을 통째로 해가지고 그거에다  이렇게 발라그내 이
# sum_score : 44.46169849421647
# bleu_socre  :  70.71
#
#
# source_text :  해서 만들어내 내가 이러 밥 히 이따만한 소쿠리 담아서
# result      :  행 만들어 내 내가 이러 밥 히 이따만한 소쿠리 담앙으네
# ground_truth:  해서 만들어내 내가 이러 밥 히 이따만한 소쿠리 담아그내
# sum_score : 45.00174565787073
# bleu_socre  :  52.56
#
#
# source_text :  어 완전 못 좋지
# result      :  어 완전 못 좋주게
# ground_truth:  어 완전 못 좋주게
# sum_score : 48.43913655425381
# bleu_socre  :  100.00
#
#
# source_text :  그거 하면 동네도 나눠줘
# result      :  그거 하믄 동네도 나눠 줘
# ground_truth:  그거 하믄 동네도 나눠줘
# sum_score : 48.313762146351245
# bleu_socre  :  46.31
#
#
# source_text :  설 명절이니까 자기네만 먹겠다고 하겠다
# result      :  설 맹질이난 지네만 먹켄 허켜게
# ground_truth:  설 명질이니까 자기네만 먹캔 하겠다
# sum_score : 46.22311842488205
# bleu_socre  :  10.68
#
#
# source_text :  우리 에 큰 어머니랑 또 작은 어머니랑 있어서 그냥 다 이
# result      :  우리 에 큰 어머니영 또 족은 어머니영 이서 그넹 그냥 다 이
# ground_truth:  우리 에 큰 어머니랑 또 작은 어머니랑 이서그내 그냥 다 이
# sum_score : 44.9621761467238
# bleu_socre  :  22.27
#
#
# source_text :  이케 오빠 와가지고 이 같이 했지
# result      :  이케 오빠 와가지고 이 같이 했주 게
# ground_truth:  이케 오빠 와가지고 이 같이 했주게
# sum_score : 45.93000244850662
# bleu_socre  :  64.32
#
#
# source_text :  그다음에 그전에 인제 또 엿 만든다고 이
# result      :  그다음 에 그전에 인제 또 엿 만든댄 이
# ground_truth:  그다음에 그전에 인제 또 엿 만든댄 이
# sum_score : 47.08284388810044
# bleu_socre  :  70.14
#
#
# source_text :  해갖고 너 엿 만들어 봤어
# result      :  해갖고 너 엿 만들어 봔
# ground_truth:  해갖고 너 엿 만들어 봔
# sum_score : 49.488169165914066
# bleu_socre  :  100.00
#
#
# source_text :  안 봤었어
# result      :  안 봤언
# ground_truth:  안 봐봔
# sum_score : 47.33650963696128
# bleu_socre  :  0.00
#
#
# source_text :  안 봤었지
# result      :  안 봐났지
# ground_truth:  안 봐봤지
# sum_score : 45.36415506875456
# bleu_socre  :  0.00
#
#
# source_text :  엿 만들때 그렇게 해
# result      :  엿 만들때 겅 해
# ground_truth:  엿 만들때 경 해
# sum_score : 44.96380242837748
# bleu_socre  :  35.36
#
#
# source_text :  막 달여 엿기름인가 뭔갈 달여서 이
# result      :  막 딸려 엿지름인가 뭔갈 딸려그넹 이
# ground_truth:  막 달여 엿기름인가 뭔갈 달여그내 이
# sum_score : 43.64527830266703
# bleu_socre  :  10.68
#
#
# source_text :  그거를 식혀서 이렇게
# result      :  그거를 식형 영
# ground_truth:  그거를 식혀그내 이렇게
# sum_score : 42.028786513679364
# bleu_socre  :  0.00
#
#
# source_text :  그렇지
# result      :  기지이
# ground_truth:  게게
# sum_score : 40.5277584239051
# bleu_socre  :  0.00
#
#
# source_text :  그렇게 해서 이렇게 해가지고 딱 잡으면 또 저쪽에서
# result      :  겅 행 영 해가지고 딱 잡으면 또 저쪽에서
# ground_truth:  겅 해서 이렇게 해가지고 딱 잡으면 또 저쪽에서
# sum_score : 40.99605044050817
# bleu_socre  :  54.11
#
#
# source_text :  탁 잡아가고 이렇게 이렇게 이렇게 이렇게 서로 이렇게
# result      :  탁 잡아 가고 영 영 영 영 서로 영
# ground_truth:  탁 잡아가고 영 영 이렇게 이렇게 서로 영
# sum_score : 40.11535413905376
# bleu_socre  :  14.58
#
#
# source_text :  그렇게 해서 엿도 만들고 이 그렇게 했지 그니까
# result      :  경 행 엿도 만들고 이 경 했주 게 게난게
# ground_truth:  그렇게 해서 엿도 만들고 이 경 했주게 그니까
# sum_score : 39.80549601071534
# bleu_socre  :  30.51
#
#
# source_text :  그렇지 그렇지
# result      :  기지 기지
# ground_truth:  기지 기지
# sum_score : 38.56157426038048
# bleu_socre  :  0.00
#
#
# source_text :  아 식구는 막 우리 거기 그쪽에 우리 또
# result      :  아 식구는 막 우리 그디 그쪽에 우리 또
# ground_truth:  아 식구는 막 우리 그디 그쪽에 우리 또
# sum_score : 40.42334473733865
# bleu_socre  :  100.00
#
#
# source_text :  육 남매에다가 뭐 우리 식구밖에 없으니까 이
# result      :  육 남매 에다가 뭐 우리 식구밖에 어시난 이
# ground_truth:  육 남매에다가 뭐 우리 식구밖에 어시난 이
# sum_score : 40.875011909995976
# bleu_socre  :  55.78
#
#
# source_text :  그렇게 했는데 우리 큰 집
# result      :  겅 해신 디 우리 큰 집
# ground_truth:  겅 해신디 우리 큰 집
# sum_score : 40.70667731978816
# bleu_socre  :  34.98
#
#
# source_text :  크 나 큰 집에서 우리 할머니도 인제 같이 사셨으니까 이
# result      :  크 나 큰 집에서 우리 할머니도 인제 같이 사셨으니까 이
# ground_truth:  크 나 큰 집에서 우리 할머니도 인제 같이 사셔시난 이
# sum_score : 41.749664866562505
# bleu_socre  :  78.25
#
#
# source_text :  우리 큰 집은 큰 집 나름대로 했던 거 같아
# result      :  우리 큰 집은 큰 집 나름대로 했던 거 닮아
# ground_truth:  우리 큰 집은 큰 집 나름대로 했던 거 닮아
# sum_score : 43.323998248547305
# bleu_socre  :  100.00
#
#
# source_text :  이렇게 했지
# result      :  영 했지
# ground_truth:  이렇게 했주게
# sum_score : 42.18389303148027
# bleu_socre  :  0.00
#
#
# source_text :  용돈 용돈 할때 세뱃돈 줄 때 어른들은 명절만 되면
# result      :  용돈 용돈 할때 세뱃돈 줄 때 어른들은 맹질만 되믄
# ground_truth:  용돈 용돈 할때 세뱃돈 줄 때 어른들은 명절만 되믄
# sum_score : 43.026931296699594
# bleu_socre  :  75.06
#
#
# source_text :  세뱃돈 일일이 다 챙기려고 하면
# result      :  세뱃돈 일일이 다 챙기젠 하면
# ground_truth:  세뱃돈 일일이 다 챙기잰 하민
# sum_score : 42.94534642524091
# bleu_socre  :  39.76
#
#
# source_text :  어어어 그렇지
# result      :  어어어 기지이
# ground_truth:  어어어 기주게
# sum_score : 41.89789895145455
# bleu_socre  :  0.00
#
#
# source_text :  그 봉투에 일일이 이름 적어가면서 누구
# result      :  그 봉투에 일일이 이름 적어가멍 누게
# ground_truth:  그 봉투에 일일이 이름 적어가멍 누구
# sum_score : 42.709462513685615
# bleu_socre  :  75.98
#
#
# source_text :  다 틀리게 담아줘야 되니까
# result      :  다 틀리게 담아줘야 되난게
# ground_truth:  다 틀리게 담아줘야 되나네
# sum_score : 43.09901817034725
# bleu_socre  :  59.46
#
#
# source_text :  그것도 식구 많으면 우리 친정집 같은 경우에 식구가
# result      :  그것도 식구 많으면 우리 친정집 같은 경우에 식구가이
# ground_truth:  것도 식구 많으면 우리 친정집 같은 경우에 식구가
# sum_score : 43.66580169674191
# bleu_socre  :  68.04
#
#
# source_text :  세뱃돈 주려고 하면
# result      :  세뱃돈 주젠 하믄 이
# ground_truth:  세뱃돈 주잰 하면
# sum_score : 42.69545054792542
# bleu_socre  :  0.00
#
#
# source_text :  어른 허리 휘겠어
# result      :  어른 허리 휘크라
# ground_truth:  어른 허리 휘켜게
# sum_score : 41.76728857949226
# bleu_socre  :  0.00
#
#
# source_text :  아이고 일 년을 모아야 되겠다
# result      :  아이고 일 년을 모아 야 되켜이
# ground_truth:  아이고 일 년을 모아야 되큰게게
# sum_score : 41.57129584659276
# bleu_socre  :  32.56
#
#
# source_text :  일 년 모아야 되고  그렇게 하고 또
# result      :  일 년 모아 야 되고 겅 하고 또
# ground_truth:  일 년 모아야 되고  겅 하고 또
# sum_score : 41.588220022346825
# bleu_socre  :  42.38
#
#
# source_text :  그렇게 했잖아 이
# result      :  겅 했잖아 이  이
# ground_truth:  경 했잖아 이
# sum_score : 40.7394808382173
# bleu_socre  :  0.00
#
#
# source_text :  할머니 할아버지가 봉투에 미리 다 담아서
# result      :  할망 하르방이 봉투에 미리 다 담앙으네
# ground_truth:  할머니 할아버지가 봉투에 미리 다 담아그내
# sum_score : 40.52896630092431
# bleu_socre  :  30.21
#
#
# source_text :  아이들 세배하면 봉투에 담아서
# result      :  아이들 세배하면 봉투에 담앙으네
# ground_truth:  아이덜 세배하면 봉투에 담앙
# sum_score : 40.36069549526527
# bleu_socre  :  31.95
#
#
# iteration num :  50
# source_text :  옷 사입은 거 이 입고 가서 세배해서 세뱃돈 받고
# result      :  옷 사입은 거 이 입엉 강 세배행 세뱃돈 받고
# ground_truth:  옷 사입은 거 이 입엉 가그내 세배해그내 세뱃돈 받고
# sum_score : 40.57173028966434
# bleu_socre  :  51.33
#
#
# source_text :  아 근데 그게 세월이 많이 바 변했더라
# result      :  아 근데 그게 세월이 많이 바 변했드라게
# ground_truth:  아 근데 그게 세월이 많이 바 변해선게
# sum_score : 41.33284238150128
# bleu_socre  :  80.91
#
#
# source_text :  나 때는 우린 우리때는 그렇게 안 했어 그냥
# result      :  나 때는 우린 우리때는 겅 안 핸 그냥
# ground_truth:  나 때는 우린 우리때는 경 안 핸 그냥
# sum_score : 41.493345300362364
# bleu_socre  :  50.00
#
#
# source_text :  어어 그래서 하루죙일 세배해 동네에  다니면서 해 해도
# result      :  어어 겡 하루죙일 세배해 동네에 댕기멍 해 해도
# ground_truth:  어어 그래서 하루죙일 세배해 동네에  다니멍이게 해 해도
# sum_score : 41.230813812223
# bleu_socre  :  27.05
#
#
# source_text :  아 그때 그렇게 했었어
# result      :  아 그때 겅 했언
# ground_truth:  아 그때 경 해난
# sum_score : 41.06503419436747
# bleu_socre  :  31.95
#
#
# source_text :  그렇지 십 원 이십 원 삼십 원 오십 원 이렇게 줬으니까
# result      :  그지 십 원 이십 원 삼십 원 오십 원 영 줘시난 에
# ground_truth:  기지 십 원 이십 원 삼십 원 오십 원 영 줬으니까
# sum_score : 41.6038334566536
# bleu_socre  :  71.78
#
#
# source_text :  벌써 오십 년 전도 넘었잖아
# result      :  벌써 오십 년 전도 넘었네
# ground_truth:  벌써 오십 년 전도 넘었네
# sum_score : 42.610663914297504
# bleu_socre  :  100.00
#
#
# source_text :  봉투가 어딨어
# result      :  봉투가 어디 서     어디 서 어디 서 어디
# ground_truth:  봉투가 어딨져게
# sum_score : 41.88844927168229
# bleu_socre  :  0.00
#
#
# source_text :  야 화장실에 가야 저기 방귀
# result      :  야 화장실에 가사 저기 방귀
# ground_truth:  야 화장실에 가사 저기 방귀
# sum_score : 42.85697511715425
# bleu_socre  :  100.00
#
#
# source_text :  신문 찾아   해서
# result      :  신문 찾아 해그넹
# ground_truth:  신문 찾아   해그내
# sum_score : 42.154401754577954
# bleu_socre  :  0.00
#
#
# source_text :  했잖아
# result      :  했네
# ground_truth:  했네
# sum_score : 41.474492048858956
# bleu_socre  :  0.00
#
#
# source_text :  지나가면서도 그냥 막 인사할려고도 하고 막 그렇게 하지 않아 이
# result      :  지나가면서도 그냥 막 인사할려고도 하고 막 겅 하지 않애 이
# ground_truth:  지나가멍도 그냥 막 인사할려고도 하고 막 겅 하지 안해 이
# sum_score : 41.864790371262394
# bleu_socre  :  66.06
#
#
# source_text :  응 아이들은 그렇게 하지 세배하려고 하면
# result      :  응 아이들은 겅 하지 세배하젠 하면
# ground_truth:  응 아이들은 겅 하지 세배허잰 하믄
# sum_score : 42.00461044070301
# bleu_socre  :  50.81
#
#
# source_text :  게 세뱃돈 받은 다음에는 또 차례 지내야 되잖아
# result      :  게 세뱃돈 받은 다음 에는 또 차례 지내 야 되네
# ground_truth:  게 세뱃돈 받아난 다음에는 또 차례 지내야 되잖아
# sum_score : 41.54553388539539
# bleu_socre  :  12.16
